# %% [markdown]
# ลงlibraryที่ใช้ในการดึงข้อมูล✅

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import pandas_datareader as data
plt.style.use("fivethirtyeight")

# %%
pip install yfinance --upgrade

# %% [markdown]
# โหลดข้อมูลdataframe จาก yahoo✅

# %%
import yfinance as yf
import datetime as dt
stock = "POWERGRID.NS"
start = dt.datetime(2000,1,1)
end = dt.datetime(2025,2,10)
df = yf.download(stock,start,end)

# %%
# df = pd.read_csv("/Users/seaconcoding/Desktop/code/miniproject_predict_stock/powergrid.csv")
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    32.385574    35.250700    26.767997    28.908793    855215656
# 2007-10-08    30.727665    33.480117    30.534510    33.480117    126671715
# 2007-10-09    32.820175    33.109906    29.085854    30.743763    116725709
# 2007-10-10    33.125999    33.802041    32.836269    33.673270     67931378
# 2007-10-11    36.828133    38.630909    32.836274    38.630909    106320954

# %%
df.shape
# Out:
# (4277, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4277 entries, 2007-10-05 to 2025-02-07
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4277 non-null   float64
#  1   (High, POWERGRID.NS)    4277 non-null   float64
#  2   (Low, POWERGRID.NS)     4277 non-null   float64
#  3   (Open, POWERGRID.NS)    4277 non-null   float64
#  4   (Volume, POWERGRID.NS)  4277 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 200.5 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4277.000000  4277.000000  4277.000000  4277.000000  4.277000e+03
# mean      82.943864    84.024654    81.881900    82.986760  1.190105e+07
# std       69.398443    70.230018    68.541233    69.400090  2.046653e+07
# min       18.908411    20.212439    16.952369    20.114637  0.000000e+00
# 25%       36.448624    36.991328    35.905464    36.505614  4.842258e+06
# 50%       57.535778    58.041997    56.727837    57.293562  8.412588e+06
# 75%       84.107315    85.139138    83.044997    84.263865  1.370196e+07
# max      356.113861   356.893408   348.074624   354.749603  8.552157e+08

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %% [markdown]
# เเสดงค่าของเเท่งเทียน 📈📉✅

# %%
df.to_csv("powergrid.csv")

# %%
data01 = pd.read_csv("powergrid.csv")

# %%
data01.head()
# Out:
#     Price        Date               Close               High  \
# 0  Ticker         NaN        POWERGRID.NS       POWERGRID.NS
# 1       0  2007-10-05   32.38557434082031   35.2507003581886
# 2       1  2007-10-08  30.727664947509766  33.48011655616869
# 3       2  2007-10-09   32.82017517089844  33.10990603070133
# 4       3  2007-10-10  33.125999450683594  33.80204096867718
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1   26.76799662291043  28.908793360303974     855215656
# 2  30.534509606022688   33.48011655616869     126671715
# 3  29.085854182395227  30.743762670622203     116725709
# 4   32.83626861907928   33.67327001215155      67931378

# %%
# สร้าง Candlestick Chart
fig = go.Figure(data=[go.Candlestick(
    x=data01['Date'],               # วันที่ (Date)
    open=data01['Open'],            # ราคาต้น (Open)
    high=data01['High'],            # ราคาสูงสุด (High)
    low=data01['Low'],              # ราคาต่ำสุด (Low)
    close=data01['Close']           # ราคาปิด (Close)
)])
# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker            POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0      2007-10-05    32.385574    35.250700    26.767997    28.908793
# 1      2007-10-08    30.727665    33.480117    30.534510    33.480117
# 2      2007-10-09    32.820175    33.109906    29.085854    30.743763
# 3      2007-10-10    33.125999    33.802041    32.836269    33.673270
# 4      2007-10-11    36.828133    38.630909    32.836274    38.630909
#
# Price        Volume
# Ticker POWERGRID.NS
# 0         855215656
# 1         126671715
# 2         116725709
# 3          67931378
# 4         106320954

# %%
df = df.drop(["Date"], axis=1)
# Out:
# <ipython-input-20-a85805975d89>:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %% [markdown]
# plot กราฟราคาปิด✅

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %% [markdown]
# plot กราฟราคาเปิด✅

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %% [markdown]
# plot กราฟราคาall time hight✅

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %% [markdown]
# plot กราฟวอลุ่มของหุ้น✅

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
import pandas as pd
ma5 = df.Close.rolling(5).mean()
ma10 = df.Close.rolling(10).mean()
ma50 = df.Close.rolling(50).mean()
ma100 = df.Close.rolling(100).mean()
ma200 = df.Close.rolling(200).mean()
ma5,ma10,ma50,ma100,ma200
# Out:
# (Ticker  POWERGRID.NS
#  0                NaN
#  1                NaN
#  2                NaN
#  3                NaN
#  4          33.177509
#  ...              ...
#  4272      288.328046
#  4273      287.893127
#  4274      285.886597
#  4275      281.833990
#  4276      280.164099
#
#  [4277 rows x 1 columns],
#  Ticker  POWERGRID.NS
#  0                NaN
#  1                NaN
#  2                NaN
#  3                NaN
#  4                NaN
#  ...              ...
#  4272      288.347815
#  4273      287.171570
#  4274      286.267148
#  4275      284.814139
#  4276      284.260901
#
#  [4277 rows x 1 columns],
#  Ticker  POWERGRID.NS
#  0                NaN
#  1                NaN
#  2                NaN
#  3                NaN
#  4                NaN
#  ...              ...
#  4272      308.006899
#  4273      306.956187
#  4274      305.887684
#  4275      304.849821
#  4276      303.900976
#
#  [4277 rows x 1 columns],
#  Ticker  POWERGRID.NS
# ...

# %% [markdown]
# สร้างเส้น sma✅

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma5, label = f'{stock} Moving Average 5 Price', linewidth = 1)
plt.plot(ma10, label = f'{stock} Moving Average 10 Price', linewidth = 1)
plt.plot(ma50, label = f'{stock} Moving Average 50 Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %% [markdown]
# สร้างเส้น ema✅

# %%
ema5 = df.Close.ewm(span=5, adjust = False).mean()
ema10 = df.Close.ewm(span=10, adjust = False).mean()
ema50 = df.Close.ewm(span=50, adjust = False).mean()
ema100 = df.Close.ewm(span=100, adjust = False).mean()
ema200 = df.Close.ewm(span=200, adjust = False).mean()
ema5,ema10,ema50,ema100,ema200
# Out:
# (Ticker  POWERGRID.NS
#  0          32.385574
#  1          31.832938
#  2          32.162017
#  3          32.483344
#  4          33.931607
#  ...              ...
#  4272      286.745371
#  4273      285.279568
#  4274      284.154111
#  4275      282.069406
#  4276      280.762935
#
#  [4277 rows x 1 columns],
#  Ticker  POWERGRID.NS
#  0          32.385574
#  1          32.084136
#  2          32.217962
#  3          32.383059
#  4          33.191254
#  ...              ...
#  4272      288.926437
#  4273      287.730350
#  4274      286.670868
#  4275      285.076164
#  4276      283.816860
#
#  [4277 rows x 1 columns],
#  Ticker  POWERGRID.NS
#  0          32.385574
#  1          32.320558
#  2          32.340151
#  3          32.370969
#  4          32.545759
#  ...              ...
#  4272      302.779928
#  4273      301.978675
#  4274      301.191401
#  4275      300.278013
#  4276      299.410247
#
#  [4277 rows x 1 columns],
#  Ticker  POWERGRID.NS
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema5, label = f'{stock} Moving Average 5 Price', linewidth = 1)
plt.plot(ema10, label = f'{stock} Moving Average 10 Price', linewidth = 1)
plt.plot(ema50, label = f'{stock} Moving Average 50 Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %% [markdown]
# สร้าง train ,test โดยtrainให้เอาข้อมูลจากclose 70%เเรกของทั้งหมด
# ส่วนtest เป็นข้อมูลที่เหลือ30%เเละที่ให้int เพราะจะเกิดeror เป็นทศนิยม✅

# %%
train = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
train
# Out:
# Ticker  POWERGRID.NS
# 0          32.385574
# 1          30.727665
# 2          32.820175
# 3          33.125999
# 4          36.828133
# ...              ...
# 2988       79.476204
# 2989       78.695015
# 2990       77.872711
# 2991       77.461548
# 2992       77.009285
#
# [2993 rows x 1 columns]

# %%
test = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])
test
# Out:
# Ticker  POWERGRID.NS
# 2993       76.721474
# 2994       77.276535
# 2995       75.138527
# 2996       74.727371
# 2997       75.960838
# ...              ...
# 4272      280.519348
# 4273      282.347961
# 4274      281.903198
# 4275      277.899994
# 4276      278.149994
#
# [1284 rows x 1 columns]

# %% [markdown]
# MinMaxScaler จำทำการnormalization ข้อมูลที่ต้องการให้อยู่ในช่วง threshold ที่กำหนด เเละนำข้อมูลtrain test ปรับscale✅

# %%
# prompt: from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))

train_arr = scaler.fit_transform(train)

# %%
train_arr.shape
# Out:
# (2993, 1)

# %% [markdown]
# เพื่อให้ เกิดการเรียนรู้ที่ดีไม่ควรfit test ด้วย เเละเพื่อให้สเกลจากtrain เป็นtest ที่ถูกต้องด้วย

# %% [markdown]
# เตรียมข้อมูล x_train ที่ใช้เทรน y_train คือข้อมูลที่ต้องทำนาย(target) ✅
# ที่เก็บy1dเพราะเก็บเเค่ค่าจริงของราคาปิด
#
# ---
#
#
# ลูปจะเริ่มต้นทำงานตั้งเเต่วันที่ 100 - 2993 เก็บข้อมูลเป็นtime serier
#
#
# *   เก็บข้อมูลย้อนหลังจาก i -100 ถึง i
# *   เก็บข้อมูล ตั้งเเต่i - 2993:

# %%
x_train = []
y_train = []

for i in range(100, train_arr.shape[0]):
    x_train.append(train_arr[i-100:i])
    y_train.append(train_arr[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2893, 100, 1)

# %%
y_train.shape
# Out:
# (2893,)

# %% [markdown]
# x_trainได้ array3d มาrow 2893 c 100 ในนั้นจะเก็บค่าไว้1
# ------------------------------------
# y_train จะเก็บแค่value ของข้อมูล sample

# %%
# xx = []
# yy = []
# t = np.array([[[100],
#         [105],
#         [110],
#         [120],
#         [125],
#         [130],
#         [135],
#         [140],
#         [145],
#         [150]]])

# for i in range(0, t.shape[0]):
#     xx.append(t[i-10:i])
#     yy.append(t[i])

# xx, yy = np.array(xx), np.array(yy)
# xx.shape

# %% [markdown]
# เริ่มสร้าง model✅
#
#
# ---
# ข้อมูลที้ใช้ในkeras(lstm) นั้นจำใช้layer เชื่อมกัน ต้องเป็นข้อมูลSequential(array3d)

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# สร้าง neuron 50 ออกจาก x_train เมื่อพreluโดยจะมีการreturn ทำให้ส่งข้อมูลออกมาเป็น3D (batch_size, time_steps, units)เเล้วส่งไปต่อ อีก60 neuron และเมื่อผ่านการ relu เเละdropout ส่งต่อไปยัง 80 neuron เหมือนก่อนหน้า เเละส่งไปยัง 120 neuron เเต่จะไม่มีการส่งsequenต่อทำให้อาเรที่ได้เป็น2d batch_size,units
#
# >dropout เป็นเทคนิคในการป้องการ overfit โดยสุ่มปิดneuron

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %% [markdown]
# เเสดง การส่ง neuron ออกมา โดยparam คือ การรวมweight biasตามสูตร (units * (input_size + units + 1))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - loss: 0.0863
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0106
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0075
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0060
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.0064
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0052
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0057
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.0049
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0048
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0044
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0044
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0045
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0045
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0040
# ...

# %% [markdown]
# เลือกข้อมูล 100วันหลังจาก train ที่เเบ่งข้อมูล70/30 เพื่อที่จะทดสอบlstm โดยการนำมาต่อกัน ที่ไม่ใช้df closeไปเลยเพราะต้องการเอา100วันสุดท้ายของtrainด้วย✅

# %%
train_p100 = train.tail(100)
sumtt = pd.concat([train_p100, test], ignore_index=True)#เพื่อให้ต่อกันจึงให้ignore_index

# %%
sumtt.head(1000)
# Out:
# Ticker  POWERGRID.NS
# 0          83.187202
# 1          83.410652
# 2          84.751404
# 3          83.979454
# 4          83.268448
# ..               ...
# 995       164.656998
# 996       165.308624
# 997       165.411545
# 998       166.851974
# 999       167.537903
#
# [1000 rows x 1 columns]

# %%
train.tail(100)
# Out:
# Ticker  POWERGRID.NS
# 2893       83.187202
# 2894       83.410652
# 2895       84.751404
# 2896       83.979454
# 2897       83.268448
# ...              ...
# 2988       79.476204
# 2989       78.695015
# 2990       77.872711
# 2991       77.461548
# 2992       77.009285
#
# [100 rows x 1 columns]

# %%
input_data = scaler.fit_transform(sumtt)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1284, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step

# %%
y_predicted.shape
# Out:
# (1284, 1)

# %%
scaler.scale_
# Out:
# array([0.00339369])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
